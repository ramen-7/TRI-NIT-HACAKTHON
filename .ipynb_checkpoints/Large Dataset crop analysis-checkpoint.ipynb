# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('cropProduction.csv')
df_damage = pd.read_csv('chemicalCropDamage.csv')

# %%
df
# Out:
#             State_Name District_Name  Crop_Year       Season          Crop  \
# 0       Andhra Pradesh     ANANTAPUR       1997  Kharif          Arhar/Tur
# 1       Andhra Pradesh     ANANTAPUR       1997  Kharif              Bajra
# 2       Andhra Pradesh     ANANTAPUR       1997  Kharif        Castor seed
# 3       Andhra Pradesh     ANANTAPUR       1997  Kharif       Cotton(lint)
# 4       Andhra Pradesh     ANANTAPUR       1997  Kharif       Dry chillies
# ...                ...           ...        ...          ...           ...
# 191852     West Bengal       PURULIA       2010  Summer              Maize
# 191853     West Bengal       PURULIA       2010  Summer               Rice
# 191854     West Bengal       PURULIA       2010  Whole Year      Sugarcane
# 191855     West Bengal       PURULIA       2010  Winter               Rice
# 191856     West Bengal       PURULIA       2010  Winter            Sesamum
#
#             Area  Production
# 0        21400.0      2600.0
# ...

# %%
df_damagae
# Out:
#        Estimated_Insects_Count Crop_Type     Soil_Type Pesticide_Use_Category  \
# 0                          188    Kharif      Alluvial           Insecticides
# 1                          209    Kharif      Alluvial           Insecticides
# 2                          257    Kharif      Alluvial           Insecticides
# 3                          257    Kharif  Black-Cotton           Insecticides
# 4                          342    Kharif      Alluvial           Insecticides
# ...                        ...       ...           ...                    ...
# 88853                     3337    Kharif      Alluvial             Herbicides
# 88854                     3516    Kharif      Alluvial             Herbicides
# 88855                     3516    Kharif      Alluvial             Herbicides
# 88856                     3702    Kharif      Alluvial             Herbicides
# 88857                     3895    Kharif      Alluvial             Herbicides
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191857 entries, 0 to 191856
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     191857 non-null  object
#  1   District_Name  191857 non-null  object
#  2   Crop_Year      191857 non-null  int64
#  3   Season         191857 non-null  object
#  4   Crop           191857 non-null  object
#  5   Area           191857 non-null  float64
#  6   Production     188974 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 10.2+ MB

# %%
print(df.State_Name.unique())
print(df.State_Name.nunique())
# Out:
# ['Andhra Pradesh' 'Arunachal Pradesh' 'Assam' 'Bihar' 'Goa' 'Gujarat'
#  'Haryana' 'Jammu and Kashmir ' 'Karnataka' 'Kerala' 'Madhya Pradesh'
#  'Maharashtra' 'Manipur' 'Meghalaya' 'Mizoram' 'Nagaland' 'Odisha'
#  'Punjab' 'Rajasthan' 'Tamil Nadu' 'Telangana ' 'Uttar Pradesh'
#  'West Bengal' 'Chandigarh' 'Dadra and Nagar Haveli' 'Himachal Pradesh'
#  'Puducherry' 'Sikkim' 'Tripura' 'Andaman and Nicobar Islands'
#  'Chhattisgarh' 'Uttarakhand' 'Jharkhand']
# 33

# %%
print(df.Season.unique() , df.Season.nunique())
# Out:
# ['Kharif     ' 'Rabi       ' 'Whole Year ' 'Autumn     ' 'Summer     '
#  'Winter     '] 6

# %%
print(df.Crop.unique(), df.Crop.nunique())
# Out:
# ['Arhar/Tur' 'Bajra' 'Castor seed' 'Cotton(lint)' 'Dry chillies'
#  'Groundnut' 'Horse-gram' 'Jowar' 'Korra' 'Maize' 'Moong(Green Gram)'
#  'Other Kharif pulses' 'Ragi' 'Rice' 'Sugarcane' 'Sunflower' 'Tobacco'
#  'Gram' 'Wheat' 'Samai' 'Sesamum' 'Urad' 'Small millets' 'Varagu' 'Mesta'
#  'Soyabean' 'Rapeseed &Mustard' 'Oilseeds total' 'Jute' 'Linseed'
#  'Other  Rabi pulses' 'Arecanut' 'Niger seed' 'Onion' 'Potato'
#  'Sweet potato' 'Tapioca' 'Turmeric' 'Dry ginger' 'Barley' 'Banana'
#  'Coriander' 'Garlic' 'Sannhamp' 'Safflower' 'Moth' 'Pulses total' 'Paddy'
#  'Black pepper' 'Cardamom' 'Cashewnut' 'Total foodgrain' 'Kapas'
#  'Peas & beans (Pulses)' 'Masoor' 'Khesari' 'Blackgram'
#  'Other Cereals & Millets' 'other oilseeds' 'Cond-spcs other' 'Tea'
#  'Guar seed' 'Jute & mesta' 'other misc. pulses' 'Rubber' 'Coffee'
#  'Beans & Mutter(Vegetable)' 'Bhindi' 'Brinjal' 'Citrus Fruit' 'Cucumber'
#  'Grapes' 'Mango' 'Orange' 'other fibres' 'Other Fresh Fruits'
# ...

# %%
df.Crop.value_counts().head(60)
# Out:
# Rice                       11759
# Maize                      10629
# Moong(Green Gram)           7697
# Urad                        7474
# Sesamum                     7165
# Groundnut                   6875
# Wheat                       6335
# Sugarcane                   6257
# Rapeseed &Mustard           6071
# Arhar/Tur                   6003
# Gram                        5964
# Jowar                       5754
# Potato                      5469
# Onion                       5442
# Dry chillies                5163
# Sunflower                   4479
# Bajra                       4466
# Small millets               3769
# Cotton(lint)                3616
# Linseed                     3575
# Barley                      3393
# Peas & beans (Pulses)       3374
# Turmeric                    3332
# Sweet potato                3285
# Ragi                        3228
# Masoor                      3213
# Other Kharif pulses         2927
# Horse-gram                  2924
# ...

# %%
crop_wise_data = []
for crop in df.Crop.unique():
    crop_wise_data.append(len(df['Crop'][df['Crop'] == crop]))
